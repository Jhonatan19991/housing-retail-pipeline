# %%
import requests
from bs4 import BeautifulSoup
from utils import get_dynamic_content_headless
import json
import time
import csv

import datetime

base_url = 'https://www.fincaraiz.com.co'

url = 'https://www.fincaraiz.com.co/venta/casas'


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'  # Para evitar bloqueos
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, 'html.parser')

# Buscar el contenedor principal
search_container = soup.find('div', class_='search-page-container')

# Asegúrate de que se encontró
listings_wrapper = search_container.find('section', class_='listingsWrapper')
    
# Buscar todas las tarjetas de propiedades
tarjets = listings_wrapper.find_all('div', class_='listingCard highlight CO')

now= datetime.datetime.now().strftime("%d/%m/%Y")

with open('../datos.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    # Escribe el encabezado
    writer.writerow(['Fecha', 'URL', 'Título', 'Constructor', 'Item', 'Unidades','Direccion_Principal', 'Direccion_Asociadas', 'lat/lon'])
    
    for tarjet in tarjets:
        # Extracción de datos existente
        info = tarjet.find('div', class_='lc-dataWrapper')
        
        # Obtener URL
        a_tag = info.find('a', class_='lc-data')
        href = a_tag['href'] if a_tag and 'href' in a_tag.attrs else None
        full_url = base_url + href if href else "No disponible"
        
        # Obtener título
        title = a_tag['title']
        
        # Obtener constructor
        constructor = "No disponible"
        publisher = info.find('div', class_='publisher')
        if publisher:
            strong_tag = publisher.find('strong')
            if strong_tag:
                constructor = strong_tag.text.strip()
        
        # Contenido dinámico
        content = get_dynamic_content_headless(full_url)

        principal_address = content[0]
        associate_address = content[1]
        item= content[2]
        units = content[3]
        lat_lon = content[4]

        time.sleep(1)
        
        # Escribe la fila directamente en cada iteración
        writer.writerow([now, full_url, title, constructor, item, units, principal_address, associate_address,lat_lon])
# Out:
# [{'m² const.': '191', 'm² priv.': '191', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 1.300.000.000'}, {'m² const.': '253.01', 'm² priv.': '253.01', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 1.550.000.000'}, {'m² const.': '253.01', 'm² priv.': '253.01', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 1.550.000.000'}, {'m² const.': '253.01', 'm² priv.': '253.01', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 1.620.000.000'}, {'m² const.': '253.01', 'm² priv.': '253.01', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 1.680.000.000'}, {'m² const.': '253.01', 'm² priv.': '253.01', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 1.680.000.000'}, {'m² const.': '253.01', 'm² priv.': '253.01', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 1.750.000.000'}, {'m² const.': '264.24', 'm² priv.': '264.24', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '4', 'Precio': '$ 1.750.000.000'}, {'m² const.': '276.42', 'm² priv.': '276.42', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '4', 'Precio': '$ 1.780.000.000'}, {'m² const.': '318.64', 'm² priv.': '318.64', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '4 Hab', 'Baños': '4', 'Precio': '$ 2.150.000.000'}, {'m² const.': '318.64', 'm² priv.': '318.64', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '4 Hab', 'Baños': '4', 'Precio': '$ 2.230.000.000'}, {'m² const.': '417.28', 'm² priv.': '417.28', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '4 Hab', 'Baños': '5', 'Precio': '$ 2.700.000.000'}, {'m² const.': '423.28', 'm² priv.': '423.28', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '4 Hab', 'Baños': '5', 'Precio': '$ 2.700.000.000'}]
# [{'m² const.': '35', 'm² priv.': '35', 'Tipo de Inmueble': 'Apartamento', 'Hab/Amb': '2 Hab', 'Baños': '1', 'Precio': '$ 170.000.000'}, {'m² const.': '194', 'm² priv.': '112', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '4', 'Precio': '$ 625.000.000'}, {'m² const.': '261', 'm² priv.': '155', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '5', 'Precio': '$ 795.000.000'}]
# [{'m² const.': '144.26', 'm² priv.': '137.55', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '2', 'Precio': '$ 700.000.000'}, {'m² const.': '167.2', 'm² priv.': '158.21', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '2', 'Precio': '$ 790.000.000'}, {'m² const.': '201.29', 'm² priv.': '192.14', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 1.024.000.000'}]
# [{'m² const.': '106', 'm² priv.': '', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 505.100.000'}]
# [{'m² const.': '106.47', 'm² priv.': '95.28', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 472.600.000'}]
# [{'m² const.': '108.24', 'm² priv.': '145.62', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '2', 'Precio': '$ 455.904.014'}]
# [{'m² const.': '84.62', 'm² priv.': '84.62', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '2 Hab', 'Baños': '2', 'Precio': '$ 395.200.000'}]
# [{'m² const.': '42.83', 'm² priv.': '66', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '2 Hab', 'Baños': '1', 'Precio': '$ 128.115.000'}, {'m² const.': '49.5', 'm² priv.': '49.5', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '2 Hab', 'Baños': '1', 'Precio': '$ 128.115.000'}, {'m² const.': '71.12', 'm² priv.': '93.12', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '2', 'Precio': '$ 192.172.500'}]
# [{'m² const.': '150', 'm² priv.': '150', 'Tipo de Inmueble': 'Lote', 'Hab/Amb': 'Abierto', 'Baños': '0', 'Precio': '$ 165.000.000'}, {'m² const.': '123', 'm² priv.': '123', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 315.000.000'}]
# [{'m² const.': '83.81', 'm² priv.': '73.25', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 591.400.000'}, {'m² const.': '96.21', 'm² priv.': '84.6', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 698.400.000'}, {'m² const.': '99.16', 'm² priv.': '86.3', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 740.400.000'}]
# [{'m² const.': '30.05', 'm² priv.': '27.45', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '1 Hab', 'Baños': '1', 'Precio': '$ 149.721.595'}]
# [{'m² const.': '41.03', 'm² priv.': '36.14', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '2 Hab', 'Baños': '1', 'Precio': '$ 149.721.595'}]
# [{'m² const.': '141', 'm² priv.': '141', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 650.400.000'}, {'m² const.': '170', 'm² priv.': '170', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 760.700.000'}]
# [{'m² const.': '120.94', 'm² priv.': '108.52', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '4', 'Precio': '$ 814.579.858'}]
# [{'m² const.': '63.33', 'm² priv.': '56.63', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '2 Hab', 'Baños': '1', 'Precio': '$ 214.602.933'}]
# [{'m² const.': '92.66', 'm² priv.': '', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '2', 'Precio': '$ 409.352.252'}, {'m² const.': '111.07', 'm² priv.': '', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '2', 'Precio': '$ 494.766.838'}]
# [{'m² const.': '190.34', 'm² priv.': '141.91', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 777.000.000'}]
# [{'m² const.': '140', 'm² priv.': '', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '2 Hab', 'Baños': '3', 'Precio': '$ 949.900.000'}, {'m² const.': '182', 'm² priv.': '', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '4 Hab', 'Baños': '5', 'Precio': '$ 1.100.330.000'}]
# [{'m² const.': '78', 'm² priv.': '78', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 360.000.000'}]
# [{'m² const.': '116.4', 'm² priv.': '106.6', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 621.464.913'}, {'m² const.': '116.4', 'm² priv.': '112.76', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 751.627.330'}]
# [{'m² const.': '134.26', 'm² priv.': '134.26', 'Tipo de Inmueble': 'Casa', 'Hab/Amb': '3 Hab', 'Baños': '3', 'Precio': '$ 550.000.000'}]
